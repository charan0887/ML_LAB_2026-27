# %% [markdown]
# <a href="https://colab.research.google.com/github/charan0887/ML_LAB_2026-27/blob/main/PAN-DAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Python Library**

# %% [markdown]
# **Introduction to Pandas**
#
# Pandas is an open-source software library written for the Python programming language, primarily used for data manipulation and analysis. It provides powerful and flexible data structures designed to make working with tabular and time-series data both easy and intuitive.

# %% [markdown]
# **Key features and functionalities of Pandas include:**
# **Data Structures:**
#
# Pandas introduces two primary data structures:
#
# **Series:** A one-dimensional labeled array capable of holding any data type. It can be thought of as a single column in a spreadsheet.
#
#
# **DataFrame:** A two-dimensional labeled data structure with columns of potentially different data types. It is similar to a spreadsheet or SQL table, providing a powerful way to represent and manipulate tabular data.

# %% [markdown]
# **What is pandas used for?**
#
# pandas is used throughout the data analysis workflow. With pandas, you can:
#
# 1. Import datasets from databases, spreadsheets, comma-separated values (CSV) files, and more.
# 2. Clean datasets, for example, by dealing with missing values.
# 3. Tidy datasets by reshaping their structure into a suitable format for analysis.
# 4. Aggregate data by calculating summary statistics such as the mean of columns, correlation between them, and more.
# 5. Visualize datasets and uncover insights.

# %% [markdown]
# **Importing data in pandas**

# %%
import pandas as pd

# %% [markdown]
# **Importing CSV files**
#
# Use **read_csv()** with the path to the CSV file to read a comma-separated values file

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# **Importing text files**

# %%
from google.colab import files

# %%
# 1. Define the research columns based on your project parameters
columns = [
    "Case_ID",
    "Age",
    "Region",
    "Marital_Status",
    "Incident_Type",
    "Precipitating_Factor",
    "Data_Source"
]

# 2. Populate rows focused strictly on the statistical categories needed for your project
data_rows = [
    ["EX-101", 28, "Urban", "Married", "Suicide", "Marital/Family Problems", "National Crime Registry / ADSI"],
    ["EX-102", 45, "Suburban", "Separated", "Suicide", "Relationship Breakdown / Legal Stress", "Vital Statistics Portal"],
    ["EX-103", 33, "Rural", "Divorced", "Suicide", "Family/Custody Disputes", "National Crime Registry / ADSI"],
    ["EX-104", 52, "Urban", "Widowed", "Suicide", "Domestic/Financial Stress", "Medical Examiner Log"]
]

# 3. Create the DataFrame (df2) using Pandas
df2 = pd.DataFrame(data_rows, columns=columns)

# %%
# 4. Save the DataFrame to an actual Excel spreadsheet format
excel_filename = "suicide_data_template.xlsx"
df2.to_excel(excel_filename, index=False)

# %%
# 5. Execute the browser download command
print("Generating your Excel spreadsheet file...")
files.download(excel_filename)
print("Check your web browser's 'Downloads' folder for 'suicide_data_template.xlsx'!")
# Out:
# Generating your Excel spreadsheet file...
# Check your web browser's 'Downloads' folder for 'suicide_data_template.xlsx'!

# %%
df2=pd.read_excel("/content/suicide_data_template.xlsx")

# %%
display(df2.head())
# Out:
#   Case_ID  Age    Region Marital_Status Incident_Type  \
# 0  EX-101   28     Urban        Married       Suicide
# 1  EX-102   45  Suburban      Separated       Suicide
# 2  EX-103   33     Rural       Divorced       Suicide
# 3  EX-104   52     Urban        Widowed       Suicide
#
#                     Precipitating_Factor                     Data_Source
# 0                Marital/Family Problems  National Crime Registry / ADSI
# 1  Relationship Breakdown / Legal Stress         Vital Statistics Portal
# 2                Family/Custody Disputes  National Crime Registry / ADSI
# 3              Domestic/Financial Stress            Medical Examiner Log

# %%
display(df2.describe())
# Out:
#              Age
# count   4.000000
# mean   39.500000
# std    10.969655
# min    28.000000
# 25%    31.750000
# 50%    39.000000
# 75%    46.750000
# max    52.000000

# %%
df2=pd.read_excel("/content/sample_data/House_Pricing_Sample_Dataset.xlsx")

# %%
display(df2)
# Out:
#   House_ID  Latitude  Longitude  Median_Age  Total_Rooms  Population  \
# 0     H001   34.0522  -118.2437          15         1200        3200
# 1     H002   34.0530  -118.2445          32          850        2100
# 2     H003   36.1699  -115.1398           8         2100        5400
# 3     H004   36.1710  -115.1410          22         1450        2800
# 4     H005   40.7128   -74.0060          45         3200        7800
# 5     H006   40.7140   -74.0075          50         2800        6200
#
#    Avg_Income_USD Proximity_to_Transit  Distance_to_Coast_km  \
# 0           85000                 High                  12.5
# 1           42000               Medium                  14.1
# 2          105000                  Low                 350.0
# 3           61000               Medium                 348.5
# 4           92000                 High                   0.8
# 5           55000                 High                   1.2
#
# ...

# %%
display(df2.describe())
# Out:
#         Latitude   Longitude  Median_Age  Total_Rooms   Population  \
# count   6.000000    6.000000    6.000000     6.000000     6.000000
# mean   36.978817 -102.463750   28.666667  1933.333333  4583.333333
# std     3.043900   22.086356   16.681327   930.412095  2231.068503
# min    34.052200 -118.244500    8.000000   850.000000  2100.000000
# 25%    34.582225 -117.468025   16.750000  1262.500000  2900.000000
# 50%    36.170450 -115.140400   27.000000  1775.000000  4300.000000
# 75%    39.577350  -84.290575   41.750000  2625.000000  6000.000000
# max    40.714000  -74.006000   50.000000  3200.000000  7800.000000
#
#        Avg_Income_USD  Distance_to_Coast_km  Crime_Rate_Index  School_Rating  \
# count        6.000000              6.000000          6.000000       6.000000
# mean     73333.333333            121.183333         33.000000       8.166667
# std      24320.087719            176.746705         10.198039       1.169045
# ...

# %% [markdown]
# **Importing Excel files**

# %%
df3=pd.read_excel("/content/sample_data/suicide_data_template.xlsx")

# %%
df3.head()
# Out:
#   Case_ID  Age    Region Marital_Status Incident_Type  \
# 0  EX-101   28     Urban        Married       Suicide
# 1  EX-102   45  Suburban      Separated       Suicide
# 2  EX-103   33     Rural       Divorced       Suicide
# 3  EX-104   52     Urban        Widowed       Suicide
#
#                     Precipitating_Factor                     Data_Source
# 0                Marital/Family Problems  National Crime Registry / ADSI
# 1  Relationship Breakdown / Legal Stress         Vital Statistics Portal
# 2                Family/Custody Disputes  National Crime Registry / ADSI
# 3              Domestic/Financial Stress            Medical Examiner Log
